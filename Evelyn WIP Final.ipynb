# %%
#Import DataFrame master_log
import pandas as pd
import numpy as np
import pickle
from pathlib import Path
data_folder = Path('Z:\\Maxime Chevee\Maxime 3\Analysis\Analysis OptoTagged 20180411')
file_to_open = data_folder / "master_log_lite.pkl"
with open(file_to_open, 'rb') as f:
    master_log = pickle.load(f, encoding='latin1')


#Final Draft of  Stimulus-aligned Histogram
L = []
for num in range(0, len(master_log.loc[:,'spike_times'])):
    adjusted_spike_times = master_log.loc[num,'spike_times']-float(master_log.loc[num,'stim_onset'])
    hist = np.histogram(adjusted_spike_times, bins=int((3-(-1))/0.025-1), range=(-1,3))
    L.append(hist)
master_log['-1to3sec_25msecbins_StimAligned'] = L

# %%
#Final Draft of Spike Raster Plot (All Trials)
import matplotlib.pyplot as plt
neuron_spike = master_log[master_log.unit_name == 'Cl4_06-05-17_TT8clst2'].spike_times - master_log[master_log.unit_name == 'Cl4_06-05-17_TT8clst2'].stim_onset
neuron_trial_num = master_log[master_log.unit_name == 'Cl4_06-05-17_TT8clst2'].trial_num
for i in range(0,len(neuron_spike)):
    x = neuron_spike[neuron_spike.index[i]]
    y = np.tile(int(neuron_trial_num[neuron_trial_num.index[i]]), len(x))
    plt.scatter(x, y, color = 'cornflowerblue')
plt.xlim(-1,3)
# Out:
# (-1, 3)

# %%
#Display all types of trials
master_log['Stim/Block/Response'].unique()
# Out:
# array(['SomMiss', 'SomFA', 'SomCR', 'SomHit', 'VisMiss', 'VisCR',
#        'VisHit', 'VisFA'], dtype=object)

# %%
#Raster Plot: SomMiss
neuron_spike_SomMiss = master_log[(master_log['Stim/Block/Response'] == 'SomMiss') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].spike_times - master_log[(master_log['Stim/Block/Response'] == 'SomMiss') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].stim_onset
neuron_trial_num_SomMiss = master_log[(master_log['Stim/Block/Response'] == 'SomMiss') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].trial_num
count = 0
for i in range(0,len(neuron_spike_SomMiss)):
    x = neuron_spike_SomMiss[neuron_spike_SomMiss.index[i]]
    y = np.tile(count, len(x))
    plt.scatter(x, y, color = 'black')
    count += 1
plt.xlim(-1,3)
plt.title('Raster Plot: Unit Cl4_06-05-17_TT8clst2, SomMiss, -1to3sec')
# Out:
# Text(0.5, 1.0, 'Raster Plot: Unit Cl4_06-05-17_TT8clst2, SomMiss, -1to3sec')

# %%
#Raster Plot: SomFA
neuron_spike_SomFA = master_log[(master_log['Stim/Block/Response'] == 'SomFA') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].spike_times - master_log[(master_log['Stim/Block/Response'] == 'SomFA') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].stim_onset
neuron_trial_num_SomFA = master_log[(master_log['Stim/Block/Response'] == 'SomFA') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].trial_num
count = 0
for i in range(0,len(neuron_spike_SomFA)):
    x = neuron_spike_SomFA[neuron_spike_SomFA.index[i]]
    y = np.tile(count, len(x))
    plt.scatter(x, y, color = 'black')
    count += 1
plt.xlim(-1,3)
plt.title('Raster Plot: Unit Cl4_06-05-17_TT8clst2, SomFA, -1to3sec')
# Out:
# Text(0.5, 1.0, 'Raster Plot: Unit Cl4_06-05-17_TT8clst2, SomFA, -1to3sec')

# %%
#Raster Plot: SomCR
neuron_spike_SomCR = master_log[(master_log['Stim/Block/Response'] == 'SomCR') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].spike_times - master_log[(master_log['Stim/Block/Response'] == 'SomCR') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].stim_onset
neuron_trial_num_SomCR = master_log[(master_log['Stim/Block/Response'] == 'SomCR') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].trial_num
count = 0
for i in range(0,len(neuron_spike_SomCR)):
    x = neuron_spike_SomCR[neuron_spike_SomCR.index[i]]
    y = np.tile(count, len(x))
    plt.scatter(x, y, color = 'black')
    count += 1
plt.xlim(-1,3)
plt.title('Raster Plot: Unit Cl4_06-05-17_TT8clst2, SomCR, -1to3sec')
# Out:
# Text(0.5, 1.0, 'Raster Plot: Unit Cl4_06-05-17_TT8clst2, SomCR, -1to3sec')

# %%
#Raster Plot: SomHit
neuron_spike_SomHit = master_log[(master_log['Stim/Block/Response'] == 'SomHit') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].spike_times - master_log[(master_log['Stim/Block/Response'] == 'SomHit') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].stim_onset
neuron_trial_num_SomHit = master_log[(master_log['Stim/Block/Response'] == 'SomHit') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].trial_num
count = 0
for i in range(0,len(neuron_spike_SomHit)):
    x = neuron_spike_SomHit[neuron_spike_SomHit.index[i]]
    y = np.tile(count, len(x))
    plt.scatter(x, y, color = 'black')
    count += 1
plt.xlim(-1,3)
plt.title('Raster Plot: Unit Cl4_06-05-17_TT8clst2, SomHit, -1to3sec')
# Out:
# Text(0.5, 1.0, 'Raster Plot: Unit Cl4_06-05-17_TT8clst2, SomHit, -1to3sec')

# %%
#Raster Plot: VisMiss
neuron_spike_VisMiss = master_log[(master_log['Stim/Block/Response'] == 'VisMiss') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].spike_times - master_log[(master_log['Stim/Block/Response'] == 'VisMiss') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].stim_onset
neuron_trial_num_VisMiss = master_log[(master_log['Stim/Block/Response'] == 'VisMiss') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].trial_num
count = 0
for i in range(0,len(neuron_spike_VisMiss)):
    x = neuron_spike_VisMiss[neuron_spike_VisMiss.index[i]]
    y = np.tile(count, len(x))
    plt.scatter(x, y, color = 'black')
    count += 1
plt.xlim(-1,3)
plt.title('Raster Plot: Unit Cl4_06-05-17_TT8clst2, VisMiss, -1to3sec')
# Out:
# Text(0.5, 1.0, 'Raster Plot: Unit Cl4_06-05-17_TT8clst2, VisMiss, -1to3sec')

# %%
#Raster Plot: VisCR
neuron_spike_VisCR = master_log[(master_log['Stim/Block/Response'] == 'VisCR') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].spike_times - master_log[(master_log['Stim/Block/Response'] == 'VisCR') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].stim_onset
neuron_trial_num_VisCR = master_log[(master_log['Stim/Block/Response'] == 'VisCR') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].trial_num
count = 0
for i in range(0,len(neuron_spike_VisCR)):
    x = neuron_spike_VisCR[neuron_spike_VisCR.index[i]]
    y = np.tile(count, len(x))
    plt.scatter(x, y, color = 'black')
    count += 1
plt.xlim(-1,3)
plt.title('Raster Plot: Unit Cl4_06-05-17_TT8clst2, VisCR, -1to3sec')
# Out:
# Text(0.5, 1.0, 'Raster Plot: Unit Cl4_06-05-17_TT8clst2, VisCR, -1to3sec')

# %%
#Raster Plot: VisHit
neuron_spike_VisHit = master_log[(master_log['Stim/Block/Response'] == 'VisHit') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].spike_times - master_log[(master_log['Stim/Block/Response'] == 'VisHit') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].stim_onset
neuron_trial_num_VisHit = master_log[(master_log['Stim/Block/Response'] == 'VisHit') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].trial_num
count = 0
for i in range(0,len(neuron_spike_VisHit)):
    x = neuron_spike_VisHit[neuron_spike_VisHit.index[i]]
    y = np.tile(count, len(x))
    plt.scatter(x, y, color = 'black')
    count += 1
plt.xlim(-1,3)
plt.title('Raster Plot: Unit Cl4_06-05-17_TT8clst2, VisHit, -1to3sec')
# Out:
# Text(0.5, 1.0, 'Raster Plot: Unit Cl4_06-05-17_TT8clst2, VisHit, -1to3sec')

# %%
#Raster Plot: VisFA
neuron_spike_VisFA = master_log[(master_log['Stim/Block/Response'] == 'VisFA') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].spike_times - master_log[(master_log['Stim/Block/Response'] == 'VisFA') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].stim_onset
neuron_trial_num_VisFA = master_log[(master_log['Stim/Block/Response'] == 'VisFA') & (master_log.unit_name == 'Cl4_06-05-17_TT8clst2')].trial_num
count = 0
for i in range(0,len(neuron_spike_VisFA)):
    x = neuron_spike_VisFA[neuron_spike_VisFA.index[i]]
    y = np.tile(count, len(x))
    plt.scatter(x, y, color = 'black')
    count += 1
plt.xlim(-1,3)
plt.title('Raster Plot: Unit Cl4_06-05-17_TT8clst2, VisFA, -1to3sec')
# Out:
# Text(0.5, 1.0, 'Raster Plot: Unit Cl4_06-05-17_TT8clst2, VisFA, -1to3sec')
