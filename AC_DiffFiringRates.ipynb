# %%
# Finalized Rate Plot (Claustrum 6)

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.patches import Rectangle
#New DataFrame
from pathlib import Path
data_folder = Path('C:\\Users\Brown Lab\Desktop\Analysis working folder\Claustrum explore')
   
# list(master_log)
#master_log_lite=master_log[
#['mouse_name',
# 'date',
# 'block_type',
# 'trial_type',
# 'touch_stimulus',
# 'vis_stimulus',
# 'response',
# 'trial_num',
# 'stim_onset',
# 'stim_offset',
# 'licks_right',
# 'licks_left',
# 'spike_times',
# 'cluster_name',
# '-0.5to2.0sec_25msecbins_StimAligned',
# 'Category',
# '-1to3sec_25msecbins_StimAligned',
#  'Stim/Block/Response',
# 'Reward',
# 'rewarded_licks',
# 'non_rewarded_licks',
# 'unit_name',
# 'LeftFirstLick',
# 'RightFirstLick',
# 'FirstLick',
# '-1to3sec_25msecbins_LickAligned',
#  'LickALigned_spike_times']]

# %%
file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart1a.pkl"
with open(file_to_open, 'rb') as f:
   master1a = pickle.load(f, encoding='latin1')

file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart1b.pkl"
with open(file_to_open, 'rb') as f:
   master1b = pickle.load(f, encoding='latin1')

file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart1c.pkl"
with open(file_to_open, 'rb') as f:
   master1c = pickle.load(f, encoding='latin1')

file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart1d.pkl"
with open(file_to_open, 'rb') as f:
   master1d = pickle.load(f, encoding='latin1')

# %%
file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart2a.pkl"
with open(file_to_open, 'rb') as f:
   master2a = pickle.load(f, encoding='latin1')

file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart2b.pkl"
with open(file_to_open, 'rb') as f:
   master2b = pickle.load(f, encoding='latin1')

file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart2c.pkl"
with open(file_to_open, 'rb') as f:
   master2c = pickle.load(f, encoding='latin1')

# %%
file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart3a.pkl"
with open(file_to_open, 'rb') as f:
   master3a = pickle.load(f, encoding='latin1')

file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart3b.pkl"
with open(file_to_open, 'rb') as f:
   master3b = pickle.load(f, encoding='latin1')

file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart3c.pkl"
with open(file_to_open, 'rb') as f:
   master3c = pickle.load(f, encoding='latin1')

file_to_open = data_folder / "Master_log_OptoSameTT_LITEpart3d.pkl"
with open(file_to_open, 'rb') as f:
   master3d = pickle.load(f, encoding='latin1')

master_log=pd.concat([master1a,master1b,master1c,master1d,master2a,master2b,master2c, master3a,master3b,master3c,master3d], axis=0)
list(master_log)
#master_log_lite=master_log[
#['mouse_name',
# 'date',
# 'block_type',
# 'trial_type',
# 'touch_stimulus',
# 'vis_stimulus',
# 'response',
# 'trial_num',
# 'stim_onset',
# 'stim_offset',
# 'licks_right',
# 'licks_left',
# 'spike_times',
# 'cluster_name',
# '-0.5to2.0sec_25msecbins_StimAligned',
# 'Category',
# '-1to3sec_25msecbins_StimAligned',
#  'Stim/Block/Response',
# 'Reward',
# 'rewarded_licks',
# 'non_rewarded_licks',
# 'unit_name',
# 'LeftFirstLick',
# 'RightFirstLick',
# 'FirstLick',
# '-1to3sec_25msecbins_LickAligned',
#  'LickALigned_spike_times']]
# Out:
# ['-1to3sec_25msecbins_LickAligned',
#  '-1to3sec_25msecbins_StimAligned',
#  'Category',
#  'Cluster_SigCorr_1secPostStim_OptoTag',
#  'Cluster_SigCorr_1secPostStim_OptoTagANDSameTT',
#  'Correct',
#  'FirstLick',
#  'LeftFirstLick',
#  'LickALigned_spike_times',
#  'LickSideCategory',
#  'Modality Preference Index',
#  'NR_Left_licks_aligned_spikes',
#  'NR_Right_licks_aligned_spikes',
#  'NR_licks_aligned_spikes',
#  'Next_LickSideCategory',
#  'Next_Reward',
#  'Next_Stim/Block/Response',
#  'Previous2_Correct',
#  'Previous2_Reward',
#  'Previous3_Correct',
#  'Previous3_Reward',
#  'Previous4_Correct',
#  'Previous4_Reward',
#  'Previous5_Correct',
#  'Previous5_Reward',
#  'Previous6_Correct',
#  'Previous6_Reward',
#  'Previous_Correct',
#  'Previous_LickSideCategory',
#  'Previous_Reward',
#  'Previous_Stim/Block/Response',
#  'Responsiveness_to_VisHit_0.05_to_0.45',
#  'Responsiveness_to_SomHit_0.05_to_0.45',
#  'Reward',
#  'Rewarded_Left_licks_aligned_spikes',
#  'Rewarded_Right_licks_aligned_spikes',
#  'Rewarded_licks_aligned_spikes',
#  'RightFirstLick',
#  'Stim/Block/Response',
#  'Trial_Start_Stop',
#  'Zscored_-1to3sec_25msecbins_StimAligned',
#  'block_type',
#  'cluster_name',
#  'date',
#  'event_detection_cma',
#  'licks_left',
#  'licks_left_trialonly',
#  'licks_right',
#  'licks_right_trialonly',
#  'mouse_name',
#  'non_rewarded_Left_licks',
#  'non_rewarded_Right_licks',
#  'non_rewarded_licks',
#  'response',
#  'rewarded_Left_licks',
#  'rewarded_Right_licks',
#  'rewarded_licks',
#  'shuffled_spike_times',
#  'spike_times',
#  'stim_offset',
#  'stim_onset',
#  'touch_stimulus',
#  'trial_num',
#  'trial_type',
#  'unit_95CI_25msecAUC_-1to3sec_SomHit_vs_SomMissVisCR',
#  'unit_95CI_25msecAUC_-1to3sec_VisHit_vs_VisMissSomCR',
#  'unit_Onset_25msecAUC_-1to3sec_SomHit_vs_SomMissVisCR',
#  'unit_Onset_25msecAUC_-1to3sec_VisHit_vs_VisMissSomCR',
#  'unit_Sig_25msecAUC_-1to3sec_SomHit_vs_SomMissVisCR',
#  'unit_Sig_25msecAUC_-1to3sec_VisHit_vs_VisMissSomCR',
#  'unit_mean_25msecAUC_-1to3sec_SomHit_vs_SomMissVisCR',
#  'unit_mean_25msecAUC_-1to3sec_VisHit_vs_VisMissSomCR',
#  'unit_name',
#  'unrewarded_licks',
#  'vis_stimulus',
#  'Cluster_PLUSvsMINUS']

# %%
# Category can be OptoTag, SameTT consider separate groups
# compare between groups
#     differences in firing rate - compare firing rates in one second preceding stimulus, one second following stimulus
#     optotagged ones seem to be responding stronger -> quantify
#
# Out:
# array(['Cl6_10-26-17_TT5clst1', 'Cl6_10-26-17_TT5clst2',
#        'Cl6_10-26-17_TT5clst3', 'Cl6_10-27-17_TT3clst1',
#        'Cl6_10-27-17_TT3clst2', 'Cl6_10-27-17_TT8clst1',
#        'Cl6_10-27-17_TT8clst2', 'Cl6_10-27-17_TT8clst4',
#        'Cl5_05-31-17_TT1clst1', 'Cl5_05-31-17_TT1clst2',
#        'Cl5_05-31-17_TT2clst1', 'Cl5_05-31-17_TT2clst2',
#        'Cl5_05-31-17_TT2clst3', 'Cl5_05-31-17_TT2clst4',
#        'Cl5_06-02-17_TT6clst1', 'Cl5_06-02-17_TT6clst2',
#        'Cl5_06-02-17_TT6clst3', 'Cl5_06-02-17_TT6clst4',
#        'Cl5_06-02-17_TT6clst5', 'Cl5_06-02-17_TT6clst6',
#        'Cl5_06-04-17_TT4clst1', 'Cl5_06-04-17_TT4clst2',
#        'Cl5_06-04-17_TT6clst1', 'Cl5_06-04-17_TT6clst2',
#        'Cl5_06-04-17_TT6clst3', 'Cl5_06-04-17_TT6clst4',
#        'Cl5_06-04-17_TT6clst5', 'Cl5_06-12-17_TT2clst1',
#        'Cl5_06-12-17_TT2clst2', 'Cl5_06-12-17_TT2clst3',
#        'Cl5_06-09-17_TT2clst1', 'Cl5_06-09-17_TT2clst2',
#        'Cl5_06-09-17_TT2clst3', 'Cl4_06-09-17_TT5clst1',
#        'Cl4_06-09-17_TT5clst2', 'Cl4_06-09-17_TT5clst3',
#        'Cl4_05-26-17_TT2clst1', 'Cl4_05-26-17_TT2clst2',
#        'Cl4_05-26-17_TT2clst3', 'Cl4_05-26-17_TT2clst4',
#        'Cl4_05-26-17_TT8clst1', 'Cl4_05-31-17_TT6clst1',
#        'Cl4_05-31-17_TT6clst2', 'Cl4_06-02-17_TT4clst1',
#        'Cl4_06-02-17_TT4clst2', 'Cl4_06-02-17_TT4clst3',
#        'Cl4_06-02-17_TT4clst4', 'Cl4_06-02-17_TT4clst5',
#        'Cl4_06-02-17_TT6clst1', 'Cl4_06-02-17_TT6clst2',
#        'Cl4_06-02-17_TT7clst1', 'Cl4_06-02-17_TT7clst2',
#        'Cl4_06-02-17_TT7clst3', 'Cl4_06-03-17_TT5clst1',
#        'Cl4_06-03-17_TT5clst2', 'Cl4_06-03-17_TT5clst3',
#        'Cl4_06-03-17_TT5clst4', 'Cl4_06-03-17_TT6clst1',
#        'Cl4_06-08-17_TT5clst1', 'Cl4_06-08-17_TT5clst2',
#        'Cl4_05-19-17_TT8clst1', 'Cl4_05-19-17_TT8clst2',
#        'Cl4_05-19-17_TT8clst3', 'Cl4_05-19-17_TT8clst4',
#        'Cl4_05-23-17_TT7clst1', 'Cl4_05-23-17_TT7clst2',
#        'Cl4_05-23-17_TT7clst3', 'Cl4_05-23-17_TT7clst4',
#        'Cl4_05-23-17_TT8clst1', 'Cl4_05-23-17_TT8clst2',
#        'Cl4_06-05-17_TT4clst1', 'Cl4_06-05-17_TT4clst2',
#        'Cl4_06-05-17_TT4clst3', 'Claustrum18_20190401_TT3clst1',
#        'Claustrum18_20190401_TT6clst1', 'Claustrum18_20190402_TT3clst1',
#        'Claustrum18_20190402_TT3clst2', 'Claustrum18_20190402_TT4clst1',
#        'Claustrum18_20190402_TT4clst2', 'Claustrum18_20190402_TT4clst3',
#        'Claustrum18_20190403_TT4clst1', 'Claustrum18_20190403_TT4clst2',
#        'Claustrum18_20190416_TT4clst1', 'Claustrum18_20190416_TT4clst2',
#        'Claustrum18_20190416_TT4clst3', 'Claustrum18_20190416_TT7clst1',
#        'Claustrum18_20190416_TT7clst2', 'Claustrum18_20190416_TT7clst3',
#        'Claustrum18_20190417_TT4clst1', 'Claustrum18_20190417_TT4clst2',
#        'Claustrum18_20190417_TT4clst3', 'Claustrum18_20190417_TT4clst4',
#        'Claustrum18_20190418_TT3clst1', 'Claustrum18_20190418_TT4clst1',
#        'Claustrum18_20190418_TT4clst2', 'Claustrum18_20190418_TT4clst3',
#        'Claustrum18_20190418_TT6clst1', 'Claustrum18_20190418_TT6clst2',
#        'Claustrum18_20190418_TT6clst3', 'Claustrum18_20190418_TT6clst4',
#        'Claustrum18_20190418_TT8clst1', 'Claustrum18_20190418_TT8clst2',
#        'Claustrum18_20190419_TT4clst1', 'Claustrum18_20190419_TT4clst2',
#        'Claustrum18_20190419_TT6clst1', 'Claustrum18_20190419_TT6clst2',
#        'Claustrum18_20190419_TT6clst3', 'Claustrum18_20190420_TT4clst1',
#        'Claustrum18_20190420_TT7clst1', 'Claustrum18_20190420_TT7clst2',
#        'Claustrum18_20190420_TT7clst3', 'Claustrum18_20190420_TT7clst4',
#        'Claustrum18_20190420_TT7clst5', 'Claustrum18_20190420_TT7clst6',
#        'Claustrum18_20190421_TT3clst1', 'Claustrum18_20190421_TT3clst2',
#        'Claustrum18_20190421_TT3clst3', 'Claustrum18_20190422_TT5clst1',
#        'Claustrum18_20190422_TT5clst2', 'Claustrum18_20190423_TT5clst1',
#        'Claustrum18_20190423_TT5clst2', 'Claustrum18_20190423_TT7clst1',
#        'Claustrum18_20190424_TT5clst1', 'Claustrum18_20190424_TT5clst2',
#        'Claustrum18_20190424_TT5clst3', 'Claustrum18_20190424_TT6clst1',
#        'Claustrum18_20190424_TT6clst2', 'Claustrum18_20190424_TT6clst3',
#        'Claustrum18_20190424_TT6clst4', 'Claustrum18_20190424_TT6clst5',
#        'Claustrum18_20190424_TT6clst6', 'Claustrum18_20190424_TT7clst1',
#        'Claustrum18_20190424_TT7clst2', 'Claustrum18_20190424_TT7clst3',
#        'Claustrum18_20190424_TT7clst4', 'Claustrum18_20190425_TT6clst1',
#        'Claustrum18_20190425_TT6clst2', 'Claustrum18_20190425_TT6clst3',
#        'Claustrum23_20190724_TT6clst1', 'Claustrum23_20190724_TT6clst2',
#        'Claustrum23_20190724_TT6clst3', 'Claustrum23_20190724_TT6clst4',
#        'Claustrum23_20190725_TT3clst1', 'Claustrum23_20190725_TT3clst2',
#        'Claustrum23_20190725_TT3clst3', 'Claustrum23_20190725_TT3clst4',
#        'Claustrum23_20190726_TT3clst1', 'Claustrum23_20190726_TT3clst2',
#        'Claustrum23_20190730_TT5clst1', 'Claustrum23_20190730_TT5clst2',
#        'Claustrum23_20190730_TT5clst3', 'Claustrum23_20190730_TT5clst4',
#        'Claustrum23_20190730_TT7clst1', 'Claustrum23_20190730_TT7clst2',
#        'Claustrum23_20190731_TT3clst1', 'Claustrum23_20190731_TT3clst2',
#        'Claustrum23_20190802_TT4clst1', 'Claustrum23_20190802_TT4clst2',
#        'Claustrum23_20190805_TT4clst1', 'Claustrum23_20190805_TT4clst2',
#        'Claustrum23_20190805_TT4clst3', 'Claustrum23_20190805_TT4clst4',
#        'Claustrum23_20190805_TT4clst5', 'Claustrum25_20190801_TT5clst1',
#        'Claustrum25_20190801_TT5clst2', 'Claustrum25_20190801_TT5clst3',
#        'Claustrum25_20190801_TT7clst1', 'Claustrum25_20190801_TT7clst2',
#        'Claustrum25_20190801_TT7clst3', 'Claustrum25_20190801_TT7clst4',
#        'Claustrum25_20190804_TT5clst1', 'Claustrum25_20190804_TT5clst2',
#        'Claustrum25_20190806_TT1clst1', 'Claustrum25_20190806_TT1clst2',
#        'Claustrum25_20190806_TT1clst3', 'Claustrum25_20190806_TT1clst4',
#        'Claustrum25_20190806_TT5clst1', 'Claustrum25_20190806_TT5clst2',
#        'Claustrum25_20190806_TT5clst3', 'Claustrum25_20190806_TT8clst1',
#        'Claustrum25_20190806_TT8clst2', 'Claustrum25_20190806_TT8clst3',
#        'Claustrum25_20190807_TT6clst1', 'Claustrum25_20190807_TT6clst2',
#        'Claustrum25_20190807_TT6clst3', 'Claustrum25_20190807_TT6clst4',
#        'Claustrum25_20190807_TT6clst5', 'Claustrum25_20190808_TT6clst1',
#        'Claustrum25_20190808_TT6clst2', 'Claustrum25_20190808_TT6clst3',
#        'Claustrum25_20190808_TT6clst4', 'Claustrum25_20190808_TT6clst5',
#        'Claustrum25_20190809_TT6clst1', 'Claustrum25_20190809_TT6clst2',
#        'Claustrum25_20190809_TT8clst1', 'Claustrum25_20190809_TT8clst2',
#        'Claustrum25_20190812_TT1clst1', 'Claustrum25_20190812_TT1clst2',
#        'Claustrum25_20190812_TT1clst3', 'Claustrum25_20190812_TT1clst4',
#        'Claustrum25_20190812_TT1clst5', 'Claustrum25_20190814_TT2clst1',
#        'Claustrum25_20190814_TT2clst2', 'Claustrum25_20190814_TT5clst1',
#        'Claustrum25_20190814_TT5clst2', 'Claustrum25_20190814_TT5clst3',
#        'Claustrum25_20190816_TT2clst1', 'Claustrum25_20190816_TT6clst1',
#        'Claustrum25_20190816_TT6clst2', 'Claustrum25_20190816_TT7clst1',
#        'Claustrum25_20190816_TT7clst2', 'Claustrum25_20190816_TT7clst3',
#        'Claustrum25_20190816_TT7clst4'], dtype=object)
